# %%
import pandas as pd
from collections import OrderedDict
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)
filmes = pd.read_csv('./data.csv', delimiter = ',')
filmes.rename(columns={"Nome": "nome", "Classificação(Anderson)": "nota","Tipo": "tipo", "Categoria": "categoria"}, inplace=True)
filmes
# Out:
#                                            nome     categoria          tipo  \
# 0                          Bata Antes de Entrar         Drama         Filme
# 1                                   O Chamado 3         Drama         Filme
# 2                                        A Babá       Comédia         Filme
# 3                              Animais Noturnos         Drama         Filme
# 4                                          1922         Crime         Série
# 5                              Ao Cair da Noite        Horror         Filme
# 6                                 Thor Ragnarok          Ação         Filme
# 7                   As Loucuras que Dick & Jane       Comédia         Filme
# 8                                      A Visita        Horror         Filme
# 9    Os Meyeriwitz: A Felicidade Não se Escolhe       Comédia         Filme
# 10                              Liga da Justiça          Ação         Filme
# 11                                      A Lista         Crime         Filme
# 12                        Ponto de Infidelidade       Comédia         Filme
# 13                                    A Viatura         Crime         Filme
# 14                                       Bright          Ação         Filme
# 15                               Terra Estranha         Drama         Filme
# 16                                O Bom Vizinho         Crime         Filme
# 17                           Vende-se Esta Casa        Horror         Filme
# 18                                  Fragmentado        Horror         Filme
# 19                                        O Bar       Comédia         Filme
# 20                                Pantera Negra          Ação         Filme
# 21                                Corpo Fechado         Drama         Filme
# 22                                     99 Casas         Drama         Filme
# 23                                       Corra!        Horror         Filme
# 24                                  Aniquilação      Aventura         Filme
# 25                  Jessica Jones - Temporada 2          Ação         Série
# 26                                   Justiceiro         Ação‎         Série
# 27                                     A Cilada         Drama         Filme
# 28                                         Lost      Aventura         Série
# 29                                    The Titan         Drama         Filme
# ..                                          ...           ...           ...
# 112                                   Stephanie        Horror         Filme
# 113                         Vingadores Ultimato          Ação         Filme
# 114                              Areia Movediça         Drama         Série
# 115                                 It: A Coisa        Horror         Filme
# 116                          Operação Fronteira          Ação         Filme
# 117                                       Vida         Horror         Filme
# 118                              Capitã Marvel           Ação         Filme
# 119                                  O Contador          Ação         Filme
# 120               Jurassic Park: Reino Ameaçado          Ação         Filme
# 121                 Três Anúncios para um Crime       Comédia         Filme
# 122                                  Jim & Andy  Documentário  Documentario
# 123                              Titãs Season 1          Ação         Série
# 124                         Um lugar silencioso         Drama         Filme
# 125                                        Mara         Crime         Filme
# 126               A Maldição da Residência Hill         Drama         Série
# 127                      Quando os anjos dormem         Drama         Filme
# 128                                 Passageiros         Drama         Filme
# 129                                  Good Omens       Comédia         Série
# 130                                     Fratura      Mistério         Filme
# 131                                     Coringa         Crime         Filme
# 132                         Seis vezes confusão       Comédia         Filme
# 133                            Contato Visceral         Drama         Filme
# 134                      Cópias de volta a vida         Drama         Filme
# 135                                    Cascavel         Drama         Filme
# 136                                     Maligno        Horror         Filme
# 137                                         Eli        Horror         Filme
# 138            John Wick Um Novo dia para Matar          Ação         Filme
# 139                    A Morte Te Dá Parabéns 2       Comédia         Filme
# 140                                   Annabelle        Horror         Filme
# 141                               Campo do Medo         Drama         Filme
#
#     nota
# 0     C-
# 1     C+
# 2     B-
# 3     A-
# 4     B-
# 5     C-
# 6     A-
# 7     B+
# 8     D-
# 9     D-
# 10    B-
# 11    B+
# 12    B-
# 13    C-
# 14    D+
# 15    C-
# 16    B+
# 17    D-
# 18    A-
# 19    C-
# 20    B+
# 21    A-
# 22    B-
# 23    B+
# 24    B-
# 25    B-
# 26    B+
# 27    B-
# 28    A-
# 29    B-
# ..   ...
# 112   C+
# 113   A+
# 114   B+
# 115   C+
# 116   B-
# 117   B-
# 118   B+
# 119   A-
# 120   B-
# 121   B-
# 122   B+
# 123   B-
# 124   B+
# 125   D+
# 126   A+
# 127   B+
# 128   C+
# 129   C+
# 130   B-
# 131   A+
# 132   D+
# 133   D+
# 134   D+
# 135   B-
# 136   B+
# 137   B+
# 138   B-
# 139   D+
# 140   C+
# 141   C+
#
# [142 rows x 4 columns]

# %%
filmes['nota'].value_counts().plot(kind='barh', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
plt.savefig('nota.png')
plt.show(),
# Out:
# (None,)

# %%
filmes['categoria'].value_counts().plot(kind='barh', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
plt.savefig('categoria.png')
plt.show()

# %%
filmes.apply(lambda x: x.factorize()[0]).corr()

sns.heatmap(pd.crosstab(filmes.categoria, filmes.nota))
plt.savefig('correlation.png')
plt.show()

# %%
X = pd.get_dummies(filmes, prefix=['tipo', 'categoria'], columns=['tipo', 'categoria'])

del X['nota']

Y = pd.get_dummies(filmes, prefix=['nota'], columns=['nota'])
Y.drop(['categoria', 'tipo'], axis=1, inplace=True)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.80, random_state=1)

# %%
from IPython import display
import pydot

from sklearn.externals.six import StringIO

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
dt_feature_names = list(X.columns)

dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data,feature_names=dt_feature_names)
dot_data.getvalue()

(graph,) = pydot.graph_from_dot_data(dot_data.getvalue())


display.Image(graph.create_png())
